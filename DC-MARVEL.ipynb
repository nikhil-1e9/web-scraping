# %%
import pandas as pd
import numpy as np

# %%
marvel_df = pd.read_csv("marvel-wikia-data.csv")
dc_df = pd.read_csv("dc-wikia-data.csv")

# %%
marvel_df['Universe'] = 'Marvel'
dc_df['Universe'] = 'DC'

# %%
dc_marvel = pd.concat([marvel_df, dc_df], ignore_index=True)
dc_marvel.drop(['GSM', 'YEAR', 'Year', 'urlslug', 'page_id'], axis=1, inplace=True)
dc_marvel
# Out:
#                                       name                ID  \
# 0                Spider-Man (Peter Parker)   Secret Identity
# 1          Captain America (Steven Rogers)   Public Identity
# 2      Wolverine (James \"Logan\" Howlett)   Public Identity
# 3        Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4                      Thor (Thor Odinson)  No Dual Identity
# ...                                    ...               ...
# 23267              Nadine West (New Earth)   Public Identity
# 23268           Warren Harding (New Earth)   Public Identity
# 23269         William Harrison (New Earth)   Public Identity
# 23270         William McKinley (New Earth)   Public Identity
# 23271                   Mookie (New Earth)   Public Identity
#
#                     ALIGN         EYE        HAIR                SEX  \
# 0         Good Characters  Hazel Eyes  Brown Hair    Male Characters
# 1         Good Characters   Blue Eyes  White Hair    Male Characters
# 2      Neutral Characters   Blue Eyes  Black Hair    Male Characters
# 3         Good Characters   Blue Eyes  Black Hair    Male Characters
# 4         Good Characters   Blue Eyes  Blond Hair    Male Characters
# ...                   ...         ...         ...                ...
# 23267     Good Characters         NaN         NaN  Female Characters
# 23268     Good Characters         NaN         NaN    Male Characters
# 23269     Good Characters         NaN         NaN    Male Characters
# 23270     Good Characters         NaN         NaN    Male Characters
# 23271      Bad Characters   Blue Eyes  Blond Hair    Male Characters
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE Universe
# 0      Living Characters       4043.0           Aug-62   Marvel
# 1      Living Characters       3360.0           Mar-41   Marvel
# 2      Living Characters       3061.0           Oct-74   Marvel
# 3      Living Characters       2961.0           Mar-63   Marvel
# 4      Living Characters       2258.0           Nov-50   Marvel
# ...                  ...          ...              ...      ...
# 23267  Living Characters          NaN              NaN       DC
# 23268  Living Characters          NaN              NaN       DC
# 23269  Living Characters          NaN              NaN       DC
# 23270  Living Characters          NaN              NaN       DC
# 23271  Living Characters          NaN              NaN       DC
#
# [23272 rows x 10 columns]

# %%
dc_marvel.dtypes
# Out:
# name                 object
# ID                   object
# ALIGN                object
# EYE                  object
# HAIR                 object
# SEX                  object
# ALIVE                object
# APPEARANCES         float64
# FIRST APPEARANCE     object
# Universe             object
# dtype: object

# %%
dc_marvel.dropna(subset='APPEARANCES', inplace=True)

# %%
dc_marvel.isna().sum()
# Out:
# name                    0
# ID                   5259
# ALIGN                3091
# EYE                 12447
# HAIR                 5822
# SEX                   852
# ALIVE                   2
# APPEARANCES             0
# FIRST APPEARANCE      675
# Universe                0
# dtype: int64

# %%
for col in ["ID", "ALIGN", "EYE", "HAIR", "SEX", "FIRST APPEARANCE"]:
    print(col+"\n")
    print(dc_marvel[col].value_counts())
    print("="*50)
# Out:
# ID
#
# Secret Identity                  8207
# Public Identity                  6642
# No Dual Identity                 1689
# Known to Authorities Identity      15
# Identity Unknown                    9
# Name: ID, dtype: int64
# ==================================================
# ALIGN
#
# Bad Characters        9076
# Good Characters       7007
# Neutral Characters    2644
# Reformed Criminals       3
# Name: ALIGN, dtype: int64
# ==================================================
# EYE
#
# Blue Eyes             2948
# Brown Eyes            2690
# Black Eyes             916
# Green Eyes             829
# Red Eyes               662
# White Eyes             471
# Yellow Eyes            325
# Grey Eyes              128
# Hazel Eyes              91
# Variable Eyes           49
# Purple Eyes             45
# Photocellular Eyes      42
# Orange Eyes             32
# Pink Eyes               23
# Gold Eyes               23
# Violet Eyes             21
# One Eye                 20
# Amber Eyes              15
# Silver Eyes             11
# Multiple Eyes            7
# No Eyes                  7
# Auburn Hair              7
# Yellow Eyeballs          6
# Black Eyeballs           3
# Magenta Eyes             2
# Compound Eyes            1
# Name: EYE, dtype: int64
# ==================================================
# HAIR
#
# Black Hair               5125
# Brown Hair               3372
# Blond Hair               2225
# No Hair                  1069
# White Hair               1045
# Red Hair                 1027
# Bald                      805
# Grey Hair                 660
# Green Hair                146
# Blue Hair                  89
# Auburn Hair                77
# Strawberry Blond Hair      75
# Purple Hair                74
# Orange Hair                63
# Pink Hair                  39
# Variable Hair              31
# Yellow Hair                18
# Silver Hair                17
# Gold Hair                  13
# Light Brown Hair            6
# Reddish Blond Hair          6
# Magenta Hair                5
# Violet Hair                 4
# Orange-brown Hair           2
# Reddish Brown Hair          2
# Platinum Blond Hair         2
# Bronze Hair                 1
# Dyed Hair                   1
# Name: HAIR, dtype: int64
# ==================================================
# SEX
#
# Male Characters           15426
# Female Characters          5479
# Agender Characters           42
# Genderless Characters        19
# Genderfluid Characters        2
# Transgender Characters        1
# Name: SEX, dtype: int64
# ==================================================
# FIRST APPEARANCE
#
# 2010, December    78
# Jun-92            69
# May-93            68
# Sep-06            67
# Oct-93            58
#                   ..
# 1974, October      1
# 1973, February     1
# 1966, August       1
# 1963, December     1
# 1946, August       1
# Name: FIRST APPEARANCE, Length: 1601, dtype: int64
# ==================================================

# %% [markdown]
# **Category Probability Imputation:** For each missing value, you can calculate the probability distribution of the categories in that column based on the non-missing values and then sample from that distribution to impute the missing value.

# %%
def impute_category_prob(df, columns):
    for column in columns:
        probabilities = df[column].value_counts(normalize=True)
        missing_indices = df[df[column].isnull()].index
        df.loc[missing_indices, column] = np.random.choice(probabilities.index, size=len(missing_indices), p=probabilities.values)

np.random.seed(43)
columns_to_impute = ['ID', 'ALIGN', 'HAIR', 'EYE']
impute_category_prob(dc_marvel, columns_to_impute)

# %%
dc_marvel.isna().sum()
# Out:
# name                  0
# ID                    0
# ALIGN                 0
# EYE                   0
# HAIR                  0
# SEX                 852
# ALIVE                 2
# APPEARANCES           0
# FIRST APPEARANCE    675
# Universe              0
# dtype: int64

# %%
for col in ["ID", "ALIGN", "EYE", "HAIR", "SEX", "FIRST APPEARANCE"]:
    print(col+"\n")
    print(dc_marvel[col].value_counts())
    print("="*50)
# Out:
# ID
#
# Secret Identity                  10764
# Public Identity                   8774
# No Dual Identity                  2248
# Known to Authorities Identity       22
# Identity Unknown                    13
# Name: ID, dtype: int64
# ==================================================
# ALIGN
#
# Bad Characters        10534
# Good Characters        8209
# Neutral Characters     3075
# Reformed Criminals        3
# Name: ALIGN, dtype: int64
# ==================================================
# EYE
#
# Blue Eyes             6841
# Brown Eyes            6369
# Black Eyes            2111
# Green Eyes            1882
# Red Eyes              1504
# White Eyes            1096
# Yellow Eyes            737
# Grey Eyes              295
# Hazel Eyes             211
# Variable Eyes          117
# Purple Eyes            113
# Photocellular Eyes     104
# Orange Eyes             86
# Violet Eyes             55
# Gold Eyes               54
# Pink Eyes               51
# One Eye                 43
# Silver Eyes             33
# Amber Eyes              31
# Auburn Hair             24
# Multiple Eyes           21
# Yellow Eyeballs         14
# No Eyes                 13
# Magenta Eyes             7
# Black Eyeballs           5
# Compound Eyes            4
# Name: EYE, dtype: int64
# ==================================================
# HAIR
#
# Black Hair               6910
# Brown Hair               4674
# Blond Hair               3016
# No Hair                  1443
# White Hair               1441
# Red Hair                 1406
# Bald                     1117
# Grey Hair                 902
# Green Hair                199
# Blue Hair                 120
# Auburn Hair               107
# Strawberry Blond Hair     105
# Purple Hair               102
# Orange Hair                86
# Pink Hair                  46
# Variable Hair              42
# Yellow Hair                28
# Silver Hair                21
# Gold Hair                  15
# Magenta Hair                9
# Reddish Blond Hair          8
# Light Brown Hair            8
# Violet Hair                 6
# Platinum Blond Hair         3
# Dyed Hair                   2
# Orange-brown Hair           2
# Reddish Brown Hair          2
# Bronze Hair                 1
# Name: HAIR, dtype: int64
# ==================================================
# SEX
#
# Male Characters           15426
# Female Characters          5479
# Agender Characters           42
# Genderless Characters        19
# Genderfluid Characters        2
# Transgender Characters        1
# Name: SEX, dtype: int64
# ==================================================
# FIRST APPEARANCE
#
# 2010, December    78
# Jun-92            69
# May-93            68
# Sep-06            67
# Oct-93            58
#                   ..
# 1974, October      1
# 1973, February     1
# 1966, August       1
# 1963, December     1
# 1946, August       1
# Name: FIRST APPEARANCE, Length: 1601, dtype: int64
# ==================================================

# %%
dc_marvel.loc[dc_marvel['SEX'].isnull(), 'SEX'] = 'Unknown'

# %%
dc_marvel.isnull().sum()
# Out:
# name                  0
# ID                    0
# ALIGN                 0
# EYE                   0
# HAIR                  0
# SEX                   0
# ALIVE                 2
# APPEARANCES           0
# FIRST APPEARANCE    675
# Universe              0
# dtype: int64

# %%
cleaned_df = dc_marvel.dropna()
cleaned_df.head()
# Out:
#                                   name                ID               ALIGN  \
# 0            Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)   Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                  Thor (Thor Odinson)  No Dual Identity     Good Characters
#
#           EYE        HAIR              SEX              ALIVE  APPEARANCES  \
# 0  Hazel Eyes  Brown Hair  Male Characters  Living Characters       4043.0
# 1   Blue Eyes  White Hair  Male Characters  Living Characters       3360.0
# 2   Blue Eyes  Black Hair  Male Characters  Living Characters       3061.0
# 3   Blue Eyes  Black Hair  Male Characters  Living Characters       2961.0
# 4   Blue Eyes  Blond Hair  Male Characters  Living Characters       2258.0
#
#   FIRST APPEARANCE Universe
# 0           Aug-62   Marvel
# 1           Mar-41   Marvel
# 2           Oct-74   Marvel
# 3           Mar-63   Marvel
# 4           Nov-50   Marvel

# %%
cleaned_df.shape
# Out:
# (21144, 10)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21144 entries, 0 to 22907
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              21144 non-null  object
#  1   ID                21144 non-null  object
#  2   ALIGN             21144 non-null  object
#  3   EYE               21144 non-null  object
#  4   HAIR              21144 non-null  object
#  5   SEX               21144 non-null  object
#  6   ALIVE             21144 non-null  object
#  7   APPEARANCES       21144 non-null  float64
#  8   FIRST APPEARANCE  21144 non-null  object
#  9   Universe          21144 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.8+ MB

# %%
cleaned_df.rename(columns={'name': 'Name',
                           'ID': 'Identity', 
                           'ALIGN': 'Alignment', 
                           'EYE': 'Eyes', 
                           'HAIR': 'Hair', 
                           'SEX': 'Sex', 
                           'ALIVE': 'Alive', 
                           'APPEARANCES': 'Appearances',
                           'FIRST APPEARANCE': 'First_appeared'}, inplace=True)
cleaned_df
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\1029273803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.rename(columns={'name': 'Name',
#                                       Name          Identity  \
# 0                Spider-Man (Peter Parker)   Secret Identity
# 1          Captain America (Steven Rogers)   Public Identity
# 2      Wolverine (James \"Logan\" Howlett)   Public Identity
# 3        Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4                      Thor (Thor Odinson)  No Dual Identity
# ...                                    ...               ...
# 22903            Gypper Zilich (New Earth)   Public Identity
# 22904             Robert Mason (New Earth)   Secret Identity
# 22905         Diablo the Horse (New Earth)   Public Identity
# 22906            Scott Scanlon (New Earth)   Public Identity
# 22907                   Gareth (New Earth)   Secret Identity
#
#                 Alignment        Eyes        Hair              Sex  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters
# 1         Good Characters   Blue Eyes  White Hair  Male Characters
# 2      Neutral Characters   Blue Eyes  Black Hair  Male Characters
# 3         Good Characters   Blue Eyes  Black Hair  Male Characters
# 4         Good Characters   Blue Eyes  Blond Hair  Male Characters
# ...                   ...         ...         ...              ...
# 22903      Bad Characters  Black Eyes  Black Hair  Male Characters
# 22904  Neutral Characters  Black Eyes  Black Hair  Male Characters
# 22905     Good Characters    Red Eyes  Black Hair  Male Characters
# 22906     Good Characters  Green Eyes  Blond Hair  Male Characters
# 22907     Good Characters  Brown Eyes  Brown Hair  Male Characters
#
#                    Alive  Appearances  First_appeared Universe
# 0      Living Characters       4043.0          Aug-62   Marvel
# 1      Living Characters       3360.0          Mar-41   Marvel
# 2      Living Characters       3061.0          Oct-74   Marvel
# 3      Living Characters       2961.0          Mar-63   Marvel
# 4      Living Characters       2258.0          Nov-50   Marvel
# ...                  ...          ...             ...      ...
# 22903  Living Characters          1.0      1941, July       DC
# 22904  Living Characters          1.0  1941, February       DC
# 22905  Living Characters          1.0   1940, January       DC
# 22906  Living Characters          1.0      1938, June       DC
# 22907  Living Characters          1.0  1936, February       DC
#
# [21144 rows x 10 columns]

# %%
cleaned_df['Name'] = cleaned_df['Name'].apply(lambda x: x.split('(')[0])
cleaned_df
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\2491571129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Name'] = cleaned_df['Name'].apply(lambda x: x.split('(')[0])
#                     Name          Identity           Alignment        Eyes  \
# 0            Spider-Man    Secret Identity     Good Characters  Hazel Eyes
# 1       Captain America    Public Identity     Good Characters   Blue Eyes
# 2             Wolverine    Public Identity  Neutral Characters   Blue Eyes
# 3              Iron Man    Public Identity     Good Characters   Blue Eyes
# 4                  Thor   No Dual Identity     Good Characters   Blue Eyes
# ...                  ...               ...                 ...         ...
# 22903     Gypper Zilich    Public Identity      Bad Characters  Black Eyes
# 22904      Robert Mason    Secret Identity  Neutral Characters  Black Eyes
# 22905  Diablo the Horse    Public Identity     Good Characters    Red Eyes
# 22906     Scott Scanlon    Public Identity     Good Characters  Green Eyes
# 22907            Gareth    Secret Identity     Good Characters  Brown Eyes
#
#              Hair              Sex              Alive  Appearances  \
# 0      Brown Hair  Male Characters  Living Characters       4043.0
# 1      White Hair  Male Characters  Living Characters       3360.0
# 2      Black Hair  Male Characters  Living Characters       3061.0
# 3      Black Hair  Male Characters  Living Characters       2961.0
# 4      Blond Hair  Male Characters  Living Characters       2258.0
# ...           ...              ...                ...          ...
# 22903  Black Hair  Male Characters  Living Characters          1.0
# 22904  Black Hair  Male Characters  Living Characters          1.0
# 22905  Black Hair  Male Characters  Living Characters          1.0
# 22906  Blond Hair  Male Characters  Living Characters          1.0
# 22907  Brown Hair  Male Characters  Living Characters          1.0
#
#        First_appeared Universe
# 0              Aug-62   Marvel
# 1              Mar-41   Marvel
# 2              Oct-74   Marvel
# 3              Mar-63   Marvel
# 4              Nov-50   Marvel
# ...               ...      ...
# 22903      1941, July       DC
# 22904  1941, February       DC
# 22905   1940, January       DC
# 22906      1938, June       DC
# 22907  1936, February       DC
#
# [21144 rows x 10 columns]

# %%
cleaned_df['Identity'].replace({'Secret Identity': 'Secret',
                                'Public Identity': 'Public',
                                'No Dual Identity': 'Non-dual',
                                'Known to Authorities Identity': 'Known to Authorities',
                                'Identity Unknown': 'Unknown'}, inplace=True)
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\3815805683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Identity'].replace({'Secret Identity': 'Secret',

# %%
cleaned_df.Identity.value_counts()
# Out:
# Secret                  10452
# Public                   8585
# Non-dual                 2072
# Known to Authorities       22
# Unknown                    13
# Name: Identity, dtype: int64

# %%
cleaned_df['Alignment'].replace({'Good Characters': 'Good',
                                 'Neutral Characters': 'Neutral',
                                 'Bad Characters': 'Bad',
                                 'Reformed Criminals': 'Bad'}, inplace=True)
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\2349068688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Alignment'].replace({'Good Characters': 'Good',

# %%
cleaned_df.Alignment.value_counts()
# Out:
# Bad        10250
# Good        7957
# Neutral     2937
# Name: Alignment, dtype: int64

# %%
cleaned_df['Eyes'] = cleaned_df['Eyes'].apply(lambda x: x.split()[0])
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\3431376347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Eyes'] = cleaned_df['Eyes'].apply(lambda x: x.split()[0])

# %%
cleaned_df.Eyes.value_counts()
# Out:
# Blue             6656
# Brown            6170
# Black            2054
# Green            1819
# Red              1459
# White            1051
# Yellow            720
# Grey              286
# Hazel             202
# Variable          113
# Purple            107
# Photocellular     104
# Orange             84
# Violet             53
# Gold               51
# Pink               48
# One                41
# Silver             32
# Amber              27
# Auburn             24
# Multiple           19
# No                 13
# Magenta             7
# Compound            4
# Name: Eyes, dtype: int64

# %%
cleaned_df['Hair'].replace({'Strawberry Blond Hair': 'Red Hair',
                            'Light Brown Hair': 'Brown Hair',
                            'Reddish Blond Hair': 'Auburn Hair',
                            'Platinum Blond Hair': 'Silver Hair',
                            'Orange-brown Hair': 'Orange Hair', 
                            'Dyed Hair': 'Blond Hair',
                            'Reddish Brown Hair': 'Red Hair',
                            'Bronze Hair': 'Blond Hair'}, inplace=True)
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\1459450016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Hair'].replace({'Strawberry Blond Hair': 'Red Hair',

# %%
cleaned_df['Hair'] = cleaned_df['Hair'].apply(lambda x: x.split()[0])
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\474703024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Hair'] = cleaned_df['Hair'].apply(lambda x: x.split()[0])

# %%
cleaned_df.Hair.value_counts()
# Out:
# Black       6688
# Brown       4552
# Blond       2927
# Red         1481
# White       1398
# No          1387
# Bald        1067
# Grey         877
# Green        193
# Blue         117
# Auburn       110
# Purple        96
# Orange        88
# Pink          43
# Variable      38
# Yellow        28
# Silver        24
# Gold          15
# Magenta        9
# Violet         6
# Name: Hair, dtype: int64

# %%
cleaned_df['Sex'] = cleaned_df['Sex'].apply(lambda x: x.split()[0])
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\1672294193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Sex'] = cleaned_df['Sex'].apply(lambda x: x.split()[0])

# %%
cleaned_df.Sex.replace({'Agender': 'Genderless'}, inplace=True)
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\1302069223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.Sex.replace({'Agender': 'Genderless'}, inplace=True)

# %%
cleaned_df.Sex.value_counts()
# Out:
# Male           14964
# Female          5301
# Unknown          824
# Genderless        52
# Genderfluid        2
# Transgender        1
# Name: Sex, dtype: int64

# %%
cleaned_df.Alive = cleaned_df.Alive.map({'Living Characters': 'Yes',
                                          'Deceased Characters': 'No'})
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\606647035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.Alive = cleaned_df.Alive.map({'Living Characters': 'Yes',

# %%
cleaned_df.Alive.value_counts()
# Out:
# Yes    16050
# No      5094
# Name: Alive, dtype: int64

# %%
cleaned_df.Appearances = cleaned_df.Appearances.astype('int64')
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\1654084432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.Appearances = cleaned_df.Appearances.astype('int64')

# %%
cleaned_df['First_appeared'].sort_values()[0:20]
# Out:
# 16607      1935, October
# 22907     1936, February
# 18084     1936, February
# 16697     1936, February
# 17844     1936, February
# 18312     1936, February
# 17081     1936, February
# 16943        1936, March
# 19216    1936, September
# 18605        1937, March
# 16761        1937, March
# 16492        1937, March
# 16557        1937, March
# 17374      1938, January
# 17117         1938, July
# 17406         1938, June
# 17438         1938, June
# 16722         1938, June
# 16458         1938, June
# 16390         1938, June
# Name: First_appeared, dtype: object

# %%
d={'Jan': 'January', 'Feb': 'February', 'Mar': 'March', 'Apr': 'April',
    'May': 'May', 'Jun': 'June', 'Jul': 'July', 'Aug': 'August', 
    'Sep': 'September', 'Oct': 'October', 'Nov': 'November', 'Dec': 'December'}

def extract_year(x):
    y = x.split('-')
    z = x.split(',')
#     m=''
    if len(y) == 2:
        x=y[1]
        m=d[y[0]]
        
        if int(x) < 15:
            x = "20"+x
        else:
            x="19"+x
        return x+', '+m
#     if len(z) == 2:
#         x=z[0]
    else:
        return x

# %%
cleaned_df.First_appeared = cleaned_df['First_appeared'].apply(extract_year)
# Out:
# C:\Users\relat\AppData\Local\Temp\ipykernel_34340\1454266243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.First_appeared = cleaned_df['First_appeared'].apply(extract_year)

# %%
cleaned_df
# Out:
#                     Name  Identity Alignment   Eyes   Hair   Sex Alive  \
# 0            Spider-Man     Secret      Good  Hazel  Brown  Male   Yes
# 1       Captain America     Public      Good   Blue  White  Male   Yes
# 2             Wolverine     Public   Neutral   Blue  Black  Male   Yes
# 3              Iron Man     Public      Good   Blue  Black  Male   Yes
# 4                  Thor   Non-dual      Good   Blue  Blond  Male   Yes
# ...                  ...       ...       ...    ...    ...   ...   ...
# 22903     Gypper Zilich     Public       Bad  Black  Black  Male   Yes
# 22904      Robert Mason     Secret   Neutral  Black  Black  Male   Yes
# 22905  Diablo the Horse     Public      Good    Red  Black  Male   Yes
# 22906     Scott Scanlon     Public      Good  Green  Blond  Male   Yes
# 22907            Gareth     Secret      Good  Brown  Brown  Male   Yes
#
#        Appearances  First_appeared Universe
# 0             4043    1962, August   Marvel
# 1             3360     1941, March   Marvel
# 2             3061   1974, October   Marvel
# 3             2961     1963, March   Marvel
# 4             2258  1950, November   Marvel
# ...            ...             ...      ...
# 22903            1      1941, July       DC
# 22904            1  1941, February       DC
# 22905            1   1940, January       DC
# 22906            1      1938, June       DC
# 22907            1  1936, February       DC
#
# [21144 rows x 10 columns]

# %%
final_df = cleaned_df.sample(frac=1).reset_index(drop=True)
final_df
# Out:
#                      Name Identity Alignment    Eyes   Hair      Sex Alive  \
# 0                  Ikonn    Secret   Neutral    Blue     No     Male   Yes
# 1           Carol Ferris    Public   Neutral    Blue  Black   Female   Yes
# 2           Vincent Edge    Public       Bad   Brown  White     Male   Yes
# 3          Thomas Adkins    Public       Bad   Brown  Black     Male   Yes
# 4              Razorback    Secret       Bad    Blue  Black     Male    No
# ...                   ...      ...       ...     ...    ...      ...   ...
# 21139             Mithra    Public      Good  Yellow  Brown     Male   Yes
# 21140  Gayle Cord-Becker    Secret      Good    Blue  Brown   Female    No
# 21141         Crazy Legs    Secret       Bad    Blue  Brown     Male   Yes
# 21142      Rio Ferdinand    Secret       Bad    Blue  Black   Female   Yes
# 21143     Four-Armed Men    Secret       Bad   Brown  Black  Unknown   Yes
#
#        Appearances   First_appeared Universe
# 0                6       1981, June   Marvel
# 1              319    1959, October       DC
# 2               16  1989, September       DC
# 3                1      2002, April   Marvel
# 4                1   1988, February       DC
# ...            ...              ...      ...
# 21139            1    1974, October   Marvel
# 21140            1  1994, September   Marvel
# 21141            4     1987, August   Marvel
# 21142            8    2006, October       DC
# 21143            1   1961, December   Marvel
#
# [21144 rows x 10 columns]

# %%
final_df.to_csv('comic_characters.csv')
